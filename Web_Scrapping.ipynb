# %% [markdown]
# <a href="https://colab.research.google.com/github/R-SIBE/Introduction-to-ML/blob/master/Web_Scrapping.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from bs4 import BeautifulSoup
from urllib.request import urlopen
import re
url = "https://en.wikipedia.org/wiki/Kevin_Bacon"
html = urlopen(url)
bs = BeautifulSoup(html.read(), 'html.parser')
for link in bs.find('div', {'id':'bodyContent'}).find_all('a', href=re.compile("^(/wiki/)((?!:).)*$")):
  if 'href' in link.attrs:
    print(link.attrs['href'])
# Out:
# /wiki/Kevin_Bacon_(disambiguation)
# /wiki/Philadelphia
# /wiki/Kyra_Sedgwick
# /wiki/Sosie_Bacon
# /wiki/Edmund_Bacon_(architect)
# /wiki/Michael_Bacon_(musician)
# /wiki/Holly_Near
# /wiki/Footloose_(1984_film)
# /wiki/JFK_(film)
# /wiki/A_Few_Good_Men
# /wiki/Apollo_13_(film)
# /wiki/Mystic_River_(film)
# /wiki/Balto_(film)
# /wiki/Sleepers
# /wiki/The_Woodsman_(2004_film)
# /wiki/Animal_House
# /wiki/Diner_(film)
# /wiki/Tremors_(film)
# /wiki/Crazy,_Stupid,_Love
# /wiki/Friday_the_13th_(1980_film)
# /wiki/Flatliners
# /wiki/The_River_Wild
# /wiki/Wild_Things_(film)
# /wiki/Stir_of_Echoes
# /wiki/Hollow_Man
# /wiki/Frost/Nixon_(film)
# /wiki/Black_Mass_(film)
# /wiki/Patriots_Day_(film)
# /wiki/Fox_Broadcasting_Company
# /wiki/The_Following
# /wiki/HBO
# /wiki/Taking_Chance
# /wiki/Golden_Globe_Award
# /wiki/Screen_Actors_Guild_Award
# /wiki/Primetime_Emmy_Award
# /wiki/I_Love_Dick_(TV_series)
# ...

# %%
import datetime as dt
import random
random.seed(dt.datetime.now())
def getlinks(articleUrl):
  url_open = urlopen('https://en.wikipedia.org{}'.format(articleUrl))
  bs = BeautifulSoup(url_open.read(),'html.parser')
  return bs.find('div',{'id':'bodyContent'}).find_all('a',href=re.compile(("^(/wiki/)((?!:).)*$")))
  
links = getlinks("/wiki/Kevin_Bacon")
while len(links)>0:
  new_article = links[random.randint(0,len(links)-1)].attrs['href']
  print(new_article)
  links = getlinks(new_article)

# %%
import urllib
from urllib import request
class AppURLopener(urllib.request.FancyURLopener):
    version = "Mozilla/5.0"
opener = AppURLopener()
pages = set()
def indiacorp(pageUrl):
  global pages
  html = opener.open(pageUrl)
  bs = BeautifulSoup(html.read(),'html5lib')
  for link in bs.find_all('a'):
    if 'href' in link.attrs:
      print(link.attrs['href'])
       
      indiacorp(newpage1) 
indiacorp('https://indiacorplaw.in/')
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:5: DeprecationWarning: AppURLopener style of invoking requests is deprecated. Use newer urlopen functions/methods
#   """
# https://indiacorplaw.in/
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /usr/lib/python3.6/urllib/request.py in open_local_file(self, url)
#    1991         try:
# -> 1992             stats = os.stat(localname)
#    1993         except OSError as e:
#
# FileNotFoundError: [Errno 2] No such file or directory: "re.compile('page')"
#
# During handling of the above exception, another exception occurred:
#
# URLError                                  Traceback (most recent call last)
# <ipython-input-31-57ba8ceebfd9> in <module>()
#      15       newpage1 = re.compile("page")
#      16       indiacorp(newpage1)
# ---> 17 indiacorp('https://indiacorplaw.in/')
#      18
#
# ...

# %%
if 'href' in link.attrs:
      if link.attrs['href'] not in pages:
        newpage = link.attrs['href']
        print(newpage)
        pages.add(newpage)
        indiacorp()
